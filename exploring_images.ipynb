# %%
from os import listdir, getcwd
from skimage.io import imread
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


from histograms import plot_image, split_layers_to_3, plot_histogram

# %%
# read in image filenames
animals_lst = listdir('images')

if '.DS_Store' in animals_lst:
    animals_lst.remove('.DS_Store')

cwd = getcwd()

animals_lst = [cwd + '/images/' + filename for filename in animals_lst]

# %%
# view a specific image
cat_image = imread(animals_lst[4])

# print(type(cat_image))
# print(cat_image.shape)

plot_image(cat_image, animals_lst[4])

r, g, b = split_layers_to_3(cat_image)

print(r.shape)
print(g.shape)
print(b.shape)
# Out:
# (150, 199)
# (150, 199)
# (150, 199)

# %%
plot_image(g, animals_lst[1])

# %%
plot_histogram(g, animals_lst[1])
